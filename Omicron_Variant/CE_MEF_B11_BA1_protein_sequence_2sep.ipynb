# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
df1 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/B11_protein/mrf_data_2months/m1.csv")
df2 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/B11_protein/mrf_data_2months/m2.csv")
df3 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/B11_protein/mrf_data_2months/m3.csv")
df4 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/B11_protein/mrf_data_2months/m4.csv")
df5 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/BA1_protein/mrf_data_2months/m1.csv")
df6 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/BA1_protein/mrf_data_2months/m2.csv")
df7 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/BA1_protein/mrf_data_2months/m3.csv")
df8 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/BA1_protein/mrf_data_2months/m4.csv")

# %%
df1['final'] = df1['final'].fillna(0)
df2['final'] = df2['final'].fillna(0)
df3['final'] = df3['final'].fillna(0)
df4['final'] = df4['final'].fillna(0)
df5['final'] = df5['final'].fillna(0)
df6['final'] = df6['final'].fillna(0)
df7['final'] = df7['final'].fillna(0)
df8['final'] = df8['final'].fillna(0)

# %%
sg_b11_m1_avg = (df1.loc[2:3823,'s_bar'].sum())
sg_b11_m2_avg = (df2.loc[2:3823,'s_bar'].sum())
sg_b11_m3_avg = (df3.loc[2:3823,'s_bar'].sum())
sg_b11_m4_avg = (df4.loc[2:3823,'s_bar'].sum())
sg_ba1_m1_avg = df5.loc[2:3823,'s_bar'].sum()
sg_ba1_m2_avg = df6.loc[2:3823,'s_bar'].sum()
sg_ba1_m3_avg = df7.loc[2:3823,'s_bar'].sum()
sg_ba1_m4_avg = df8.loc[2:3823,'s_bar'].sum()

sg_b11_m1_mrf = (df1.loc[2:3823,'final'].sum())
sg_b11_m2_mrf = (df2.loc[2:3823,'final'].sum())
sg_b11_m3_mrf = (df3.loc[2:3823,'final'].sum())
sg_b11_m4_mrf = (df4.loc[2:3823,'final'].sum())
sg_ba1_m1_mrf = df5.loc[2:3823,'final'].sum()
sg_ba1_m2_mrf = df6.loc[2:3823,'final'].sum()
sg_ba1_m3_mrf = df7.loc[2:3823,'final'].sum()
sg_ba1_m4_mrf = df8.loc[2:3823,'final'].sum()

# %%
ntd_b11_m1_avg = (df1.loc[33:910,'s_bar'].sum())
ntd_b11_m2_avg = (df2.loc[33:910,'s_bar'].sum())
ntd_b11_m3_avg = (df3.loc[33:910,'s_bar'].sum())
ntd_b11_m4_avg = (df4.loc[33:910,'s_bar'].sum())
ntd_ba1_m1_avg = df5.loc[33:910,'s_bar'].sum()
ntd_ba1_m2_avg = df6.loc[33:910,'s_bar'].sum()
ntd_ba1_m3_avg = df7.loc[33:910,'s_bar'].sum()
ntd_ba1_m4_avg = df8.loc[33:910,'s_bar'].sum()

ntd_b11_m1_mrf = (df1.loc[33:910,'final'].sum())
ntd_b11_m2_mrf = (df2.loc[33:910,'final'].sum())
ntd_b11_m3_mrf = (df3.loc[33:910,'final'].sum())
ntd_b11_m4_mrf = (df4.loc[33:910,'final'].sum())
ntd_ba1_m1_mrf = df5.loc[33:910,'final'].sum()
ntd_ba1_m2_mrf = df6.loc[33:910,'final'].sum()
ntd_ba1_m3_mrf = df7.loc[33:910,'final'].sum()
ntd_ba1_m4_mrf = df8.loc[33:910,'final'].sum()

# %%
rbd_b11_m1_avg = (df1.loc[956:1623,'s_bar'].sum())
rbd_b11_m2_avg = (df2.loc[956:1623,'s_bar'].sum())
rbd_b11_m3_avg = (df3.loc[956:1623,'s_bar'].sum())
rbd_b11_m4_avg = (df4.loc[956:1623,'s_bar'].sum())
rbd_ba1_m1_avg = df5.loc[956:1623,'s_bar'].sum()
rbd_ba1_m2_avg = df6.loc[956:1623,'s_bar'].sum()
rbd_ba1_m3_avg = df7.loc[956:1623,'s_bar'].sum()
rbd_ba1_m4_avg = df8.loc[956:1623,'s_bar'].sum()

rbd_b11_m1_mrf = (df1.loc[956:1623,'final'].sum())
rbd_b11_m2_mrf = (df2.loc[956:1623,'final'].sum())
rbd_b11_m3_mrf = (df3.loc[956:1623,'final'].sum())
rbd_b11_m4_mrf = (df4.loc[956:1623,'final'].sum())
rbd_ba1_m1_mrf = df5.loc[956:1623,'final'].sum()
rbd_ba1_m2_mrf = df6.loc[956:1623,'final'].sum()
rbd_ba1_m3_mrf = df7.loc[956:1623,'final'].sum()
rbd_ba1_m4_mrf = df8.loc[956:1623,'final'].sum()

# %%
b11_avg = [sg_b11_m1_avg,sg_b11_m2_avg,sg_b11_m3_avg,sg_b11_m4_avg]
ntd_b11_avg = [ntd_b11_m1_avg,ntd_b11_m2_avg,ntd_b11_m3_avg,ntd_b11_m4_avg]
rbd_b11_avg = [rbd_b11_m1_avg,rbd_b11_m2_avg,rbd_b11_m3_avg,rbd_b11_m4_avg]

ba1_avg = [sg_ba1_m1_avg,sg_ba1_m2_avg,sg_ba1_m3_avg,sg_ba1_m4_avg]
ntd_ba1_avg = [ntd_ba1_m1_avg,ntd_ba1_m2_avg,ntd_ba1_m3_avg,ntd_ba1_m4_avg]
rbd_ba1_avg = [rbd_ba1_m1_avg,rbd_ba1_m2_avg,rbd_ba1_m3_avg,rbd_ba1_m4_avg]

b11_mrf = [sg_b11_m1_mrf,sg_b11_m2_mrf,sg_b11_m3_mrf,sg_b11_m4_mrf]
ntd_b11_mrf = [ntd_b11_m1_mrf,ntd_b11_m2_mrf,ntd_b11_m3_mrf,ntd_b11_m4_mrf]
rbd_b11_mrf = [rbd_b11_m1_mrf,rbd_b11_m2_mrf,rbd_b11_m3_mrf,rbd_b11_m4_mrf]

ba1_mrf = [sg_ba1_m1_mrf,sg_ba1_m2_mrf,sg_ba1_m3_mrf,sg_ba1_m4_mrf]
ntd_ba1_mrf = [ntd_ba1_m1_mrf,ntd_ba1_m2_mrf,ntd_ba1_m3_mrf,ntd_ba1_m4_mrf]
rbd_ba1_mrf = [rbd_ba1_m1_mrf,rbd_ba1_m2_mrf,rbd_ba1_m3_mrf,rbd_ba1_m4_mrf]

# %%
x1 = np.arange(0,4)
x2 = np.arange(3,7)
label = ["May-Jun21","Jul-Aug21","Sep-Oct21","Nov-Dec21","Jan-Feb22","Mar-Apr22","May-Jun22"]
ticks = [0,1,2,3,4,5,6]

fig, axs = plt.subplots(2, 2, figsize=(18,10))
axs[0, 0].plot(x1, b11_avg, '-ro', label="B11 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].plot(x2, ba1_avg, '-bo', label="BA1 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].legend(frameon=False)
axs[0, 0].set_xticks(ticks,label)
axs[0, 0].tick_params(labelsize=12)
axs[0, 1].plot(x1,ntd_b11_avg, '-ro', label="B11 NTD", linewidth=4.0)
axs[0, 1].plot(x2,ntd_ba1_avg, '-bo', label="BA1 NTD", linewidth=4.0)
axs[0, 1].legend(frameon=False)
axs[0, 1].set_xticks(ticks,label)
axs[0, 1].tick_params(labelsize=12)
axs[1, 0].plot(x1,b11_mrf, '-ro', label="B11 Surface Glycoprotein", linewidth=4.0)
axs[1, 0].plot(x2,ba1_mrf, '-bo', label="BA1 Surface Glycoprotein", linewidth=4.0)
axs[1, 0].legend(frameon=False)
axs[1, 0].tick_params(labelsize=12)
axs[1, 0].set_xticks(ticks,label)
axs[1, 1].plot(x1,ntd_b11_mrf, '-ro', label="B11 NTD", linewidth=4.0)
axs[1, 1].plot(x2,ntd_ba1_mrf, '-bo', label="BA1 NTD", linewidth=4.0)
axs[1, 1].legend(frameon=False)
axs[1, 1].set_xticks(ticks,label)
axs[1, 1].tick_params(labelsize=12)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_mrf_b11_ba1_combine_2sep_sg_ntd_protein.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
label = ["May-Jun21","Jul-Aug21","Sep-Oct21","Nov-Dec21","Jan-Feb22","Mar-Apr22","May-Jun22"]
ticks = [0,1,2,3,4,5,6]

x1_mrf = np.arange(0,4)
x2_mrf = np.arange(3,7)

plt.figure(figsize=(16,5))
plt.plot(x1,rbd_b11_avg, '-ro', linewidth=3.0, label="B11 RBD")
plt.plot(x2,rbd_ba1_avg, '-bo', linewidth=3.0, label="BA1 RBD")
plt.xticks(ticks,label, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_b11_ba1_combine_2sep_rbd_protein.png", dpi=600)
plt.show()

plt.figure(figsize=(16,5))
plt.plot(x1,rbd_b11_mrf, '-ro', linewidth=3.0, label="B11 RBD")
plt.plot(x2,rbd_ba1_mrf, '-bo', linewidth=3.0, label="BA1 RBD")
plt.xticks(ticks,label, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/mrf_b11_ba1_combine_2sep_rbd_protein.png", dpi=600)
plt.show()
