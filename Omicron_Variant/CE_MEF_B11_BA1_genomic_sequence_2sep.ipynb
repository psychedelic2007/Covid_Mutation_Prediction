# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
combined_b11_df = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/B11_genomic/entropy_csv_log10/combined_b11_usa_log10.csv")
combined_ba1_df = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/BA1_genomic/entropy_csv_log10/combined_ba1_usa_log10.csv")

# %%
d1 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/B11_genomic/mrf_data_3months/m1.csv")
d2 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/B11_genomic/mrf_data_3months/m2.csv")
d3 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/B11_genomic/mrf_data_3months/m3.csv")
d4 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/BA1_genomic/mrf_data_3new/m1.csv")
d5 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/BA1_genomic/mrf_data_3new/m2.csv")
d6 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/BA1_genomic/mrf_data_3new/m3.csv")
d7 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/Omicron_calculation/USA/Genomic/BA1_genomic/mrf_data_3new/m4.csv")

# %%
d1['final'] = d1['final'].fillna(0)
d2['final'] = d2['final'].fillna(0)
d3['final'] = d3['final'].fillna(0)
d4['final'] = d4['final'].fillna(0)
d5['final'] = d5['final'].fillna(0)
d6['final'] = d6['final'].fillna(0)
d7['final'] = d7['final'].fillna(0)

# %%
sg_b11_m1_avg = (d1.loc[2:3823,'s_bar'].sum())
sg_b11_m2_avg = (d2.loc[2:3823,'s_bar'].sum())
sg_b11_m3_avg = (d3.loc[2:3823,'s_bar'].sum())
sg_ba1_m1_avg = d4.loc[2:3823,'s_bar'].sum()
sg_ba1_m2_avg = d5.loc[2:3823,'s_bar'].sum()
sg_ba1_m3_avg = d6.loc[2:3823,'s_bar'].sum()
sg_ba1_m4_avg = d7.loc[2:3823,'s_bar'].sum()

ntd_b11_m1_avg = (d1.loc[33:910,'s_bar'].sum())
ntd_b11_m2_avg = (d2.loc[33:910,'s_bar'].sum())
ntd_b11_m3_avg = (d3.loc[33:910,'s_bar'].sum())
ntd_ba1_m1_avg = d4.loc[33:910,'s_bar'].sum()
ntd_ba1_m2_avg = d5.loc[33:910,'s_bar'].sum()
ntd_ba1_m3_avg = d6.loc[33:910,'s_bar'].sum()
ntd_ba1_m4_avg = d7.loc[33:910,'s_bar'].sum()

rbd_b11_m1_avg = (d1.loc[956:1622,'s_bar'].sum())
rbd_b11_m2_avg = (d2.loc[956:1622,'s_bar'].sum())
rbd_b11_m3_avg = (d3.loc[956:1622,'s_bar'].sum())
rbd_ba1_m1_avg = d4.loc[956:1622,'s_bar'].sum()
rbd_ba1_m2_avg = d5.loc[956:1622,'s_bar'].sum()
rbd_ba1_m3_avg = d6.loc[956:1622,'s_bar'].sum()
rbd_ba1_m4_avg = d7.loc[956:1622,'s_bar'].sum()

sg_b11_m1_mrf = (d1.loc[2:3823,'final'].sum())
sg_b11_m2_mrf = (d2.loc[2:3823,'final'].sum())
sg_b11_m3_mrf = (d3.loc[2:3823,'final'].sum())
sg_ba1_m1_mrf = (d4.loc[2:3823,'final'].sum())
sg_ba1_m2_mrf = (d5.loc[2:3823,'final'].sum())
sg_ba1_m3_mrf = (d6.loc[2:3823,'final'].sum())
sg_ba1_m4_mrf = (d7.loc[2:3823,'final'].sum())

ntd_b11_m1_mrf = (d1.loc[33:910,'final'].sum())
ntd_b11_m2_mrf = (d2.loc[33:910,'final'].sum())
ntd_b11_m3_mrf = (d3.loc[33:910,'final'].sum())
ntd_ba1_m1_mrf = (d4.loc[33:910,'final'].sum())
ntd_ba1_m2_mrf = (d5.loc[33:910,'final'].sum())
ntd_ba1_m3_mrf = (d6.loc[33:910,'final'].sum())
ntd_ba1_m4_mrf = (d7.loc[33:910,'final'].sum())

rbd_b11_m1_mrf = (d1.loc[956:1622,'final'].sum())
rbd_b11_m2_mrf = (d2.loc[956:1622,'final'].sum())
rbd_b11_m3_mrf = (d3.loc[956:1622,'final'].sum())
rbd_ba1_m1_mrf = (d4.loc[956:1622,'final'].sum())
rbd_ba1_m2_mrf = (d5.loc[956:1622,'final'].sum())
rbd_ba1_m3_mrf = (d6.loc[956:1622,'final'].sum())
rbd_ba1_m4_mrf = (d7.loc[956:1622,'final'].sum())

# %%
sg_b11_avg = [sg_b11_m1_avg,sg_b11_m2_avg,sg_b11_m3_avg]
ntd_b11_avg = [ntd_b11_m1_avg,ntd_b11_m2_avg,ntd_b11_m3_avg]
rbd_b11_avg = [rbd_b11_m1_avg,rbd_b11_m2_avg,rbd_b11_m3_avg]

sg_ba1_avg = [sg_ba1_m1_avg,sg_ba1_m2_avg,sg_ba1_m3_avg,sg_ba1_m4_avg]
ntd_ba1_avg = [ntd_ba1_m1_avg,ntd_ba1_m2_avg,ntd_ba1_m3_avg,sg_ba1_m4_avg]
rbd_ba1_avg = [rbd_ba1_m1_avg,rbd_ba1_m2_avg,rbd_ba1_m3_avg,sg_ba1_m4_avg]

sg_b11_mrf = [sg_b11_m1_mrf,sg_b11_m2_mrf,sg_b11_m3_mrf]
ntd_b11_mrf = [ntd_b11_m1_mrf,ntd_b11_m2_mrf,ntd_b11_m3_mrf]
rbd_b11_mrf = [rbd_b11_m1_mrf,rbd_b11_m2_mrf,rbd_b11_m3_mrf]

sg_ba1_mrf = [sg_ba1_m1_mrf,sg_ba1_m2_mrf,sg_ba1_m3_mrf,sg_ba1_m4_mrf]
ntd_ba1_mrf = [ntd_ba1_m1_mrf,ntd_ba1_m2_mrf,ntd_ba1_m3_mrf,sg_ba1_m4_mrf]
rbd_ba1_mrf = [rbd_ba1_m1_mrf,rbd_ba1_m2_mrf,rbd_ba1_m3_mrf,sg_ba1_m4_mrf]

x1 = np.arange(0,3)
x2 = np.arange(2,6)
label = ["Dec-Feb2021","Mar-May2021","Jun-Aug2021","Sep-Nov2021","Dec-Feb2022","Mar-May2022"]
ticks = [0,1,2,3,4,5]

fig, axs = plt.subplots(2, 2, figsize=(18,10))
axs[0, 0].plot(x1, sg_b11_avg, '-ro', label="B11 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].plot(x2, sg_ba1_avg, '-bo', label="BA1 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].legend(frameon=False)
axs[0, 0].set_xticks(ticks,label)
axs[0, 0].tick_params(labelsize=12)
axs[0, 1].plot(x1,ntd_b11_avg, '-ro', label="B11 NTD", linewidth=4.0)
axs[0, 1].plot(x2,ntd_ba1_avg, '-bo', label="BA1 NTD", linewidth=4.0)
axs[0, 1].legend(frameon=False)
axs[0, 1].set_xticks(ticks,label)
axs[0, 1].tick_params(labelsize=12)
axs[1, 0].plot(x1,sg_b11_mrf, '-ro', label="B11 Surface Glycoprotein", linewidth=4.0)
axs[1, 0].plot(x2,sg_ba1_mrf, '-bo', label="BA1 Surface Glycoprotein", linewidth=4.0)
axs[1, 0].legend(frameon=False)
axs[1, 0].tick_params(labelsize=12)
axs[1, 0].set_xticks(ticks,label)
axs[1, 1].plot(x1,ntd_b11_mrf, '-ro', label="B11 NTD", linewidth=4.0)
axs[1, 1].plot(x2,ntd_ba1_mrf, '-bo', label="BA1 NTD", linewidth=4.0)
axs[1, 1].legend(frameon=False)
axs[1, 1].set_xticks(ticks,label)
axs[1, 1].tick_params(labelsize=12)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_mrf_b11_ba1_combine_2sep_sg_ntd_genomic.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
label_mrf = ["Apr-Jun20","Jul-Sep20","Oct-Dec20","Jan-Mar21","April-Jun21","Jul-Sep21"]#,"Oct-Dec21"]
ticks_mrf = [0,1,2,3,4,5]

x1_mrf = np.arange(0,4)
x2_mrf = np.arange(3,6)

plt.figure(figsize=(16,5))
plt.plot(x1,rbd_b11_avg, '-ro', linewidth=3.0, label="B11 RBD")
plt.plot(x2,rbd_ba1_avg, '-bo', linewidth=3.0, label="BA1 RBD")
plt.xticks(ticks_mrf,label_mrf, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_b11_ba1_combine_2sep_rbd_genomic.png", dpi=600)
plt.show()

plt.figure(figsize=(16,5))
plt.plot(x1,rbd_b11_mrf, '-ro', linewidth=3.0, label="B11 RBD")
plt.plot(x2,rbd_ba1_mrf, '-bo', linewidth=3.0, label="BA1 RBD")
plt.xticks(ticks_mrf,label_mrf, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/mrf_b11_ba1_combine_2sep_rbd_genomic.png", dpi=600)
plt.show()
