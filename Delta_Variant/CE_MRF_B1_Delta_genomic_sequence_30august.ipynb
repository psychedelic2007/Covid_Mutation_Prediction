# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/updated_b1_data_trimester/tri1.csv")
df1['final'] = df1['final'].fillna(0)

df2 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/updated_b1_data_trimester/tri2.csv")
df2['final'] = df2['final'].fillna(0)

df3 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/updated_b1_data_trimester/tri3.csv")
df3['final'] = df3['final'].fillna(0)

df4 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/updated_b1_data_trimester/tri4.csv")
df4['final'] = df4['final'].fillna(0)

df5 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/updated_b1_data_trimester/tri5.csv")
df5['final'] = df5['final'].fillna(0)

df6 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/Delta/tri1.csv")
df6['final'] = df6['final'].fillna(0)

df7 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/Delta/tri2.csv")
df7['final'] = df7['final'].fillna(0)

df8 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/Delta/tri3.csv")
df8['final'] = df8['final'].fillna(0)

df9 = pd.read_csv("/home/satyam/Documents/Projects/Entropy_Comparison/GISAID/India/Delta/tri4.csv")
df9['final'] = df9['final'].fillna(0)

# %%
#calculating the mrf for whole glycoprotein sequence

b1_q1_avg = df1.loc[2:3823,'s_bar'].sum()
b1_q2_avg = df2.loc[2:3823,'s_bar'].sum()
b1_q3_avg = df3.loc[2:3823,'s_bar'].sum()
b1_q4_avg = df4.loc[2:3823,'s_bar'].sum()
b1_q5_avg = df5.loc[2:3823,'s_bar'].sum()
delta_q6_avg = df6.loc[2:3823,'s_bar'].sum()
delta_q7_avg = df7.loc[2:3823,'s_bar'].sum()
delta_q8_avg = df8.loc[2:3823,'s_bar'].sum()
delta_q9_avg = df9.loc[2:3823,'s_bar'].sum()

b1_q1_mrf = df1.loc[2:3823,'final'].sum()
b1_q2_mrf = df2.loc[2:3823,'final'].sum()
b1_q3_mrf = df3.loc[2:3823,'final'].sum()
b1_q4_mrf = df4.loc[2:3823,'final'].sum()
b1_q5_mrf = df5.loc[2:3823,'final'].sum()
delta_q6_mrf = df6.loc[2:3823,'final'].sum()
delta_q7_mrf = df7.loc[2:3823,'final'].sum()
delta_q8_mrf = df8.loc[2:3823,'final'].sum()
delta_q9_mrf = df9.loc[2:3823,'final'].sum()

# %%
#calculating the mrf for ntd domain

ntd_q1_avg = df1.loc[33:910,'s_bar'].sum()
ntd_q2_avg = df2.loc[33:910,'s_bar'].sum()
ntd_q3_avg = df3.loc[33:910,'s_bar'].sum()
ntd_q4_avg = df4.loc[33:910,'s_bar'].sum()
ntd_q5_avg = df5.loc[33:910,'s_bar'].sum()
ntd_q6_avg = df6.loc[33:910,'s_bar'].sum()
ntd_q7_avg = df7.loc[33:910,'s_bar'].sum()
ntd_q8_avg = df8.loc[33:910,'s_bar'].sum()
ntd_q9_avg = df9.loc[33:910,'s_bar'].sum()

ntd_q1_mrf = df1.loc[33:910,'final'].sum()
ntd_q2_mrf = df2.loc[33:910,'final'].sum()
ntd_q3_mrf = df3.loc[33:910,'final'].sum()
ntd_q4_mrf = df4.loc[33:910,'final'].sum()
ntd_q5_mrf = df5.loc[33:910,'final'].sum()
ntd_q6_mrf = df6.loc[33:910,'final'].sum()
ntd_q7_mrf = df7.loc[33:910,'final'].sum()
ntd_q8_mrf = df8.loc[33:910,'final'].sum()
ntd_q9_mrf = df9.loc[33:910,'final'].sum()

# %%
#calculating the mrf for rbd domain

rbd_q1_avg = df1.loc[955:1623,'s_bar'].sum()
rbd_q2_avg = df2.loc[955:1623,'s_bar'].sum()
rbd_q3_avg = df3.loc[955:1623,'s_bar'].sum()
rbd_q4_avg = df4.loc[955:1623,'s_bar'].sum()
rbd_q5_avg = df5.loc[955:1623,'s_bar'].sum()
rbd_q6_avg = df6.loc[955:1623,'s_bar'].sum()
rbd_q7_avg = df7.loc[955:1623,'s_bar'].sum()
rbd_q8_avg = df8.loc[955:1623,'s_bar'].sum()
rbd_q9_avg = df9.loc[955:1623,'s_bar'].sum()

rbd_q1_mrf = df1.loc[955:1623,'final'].sum()
rbd_q2_mrf = df2.loc[955:1623,'final'].sum()
rbd_q3_mrf = df3.loc[955:1623,'final'].sum()
rbd_q4_mrf = df4.loc[955:1623,'final'].sum()
rbd_q5_mrf = df5.loc[955:1623,'final'].sum()
rbd_q6_mrf = df6.loc[955:1623,'final'].sum()
rbd_q7_mrf = df7.loc[955:1623,'final'].sum()
rbd_q8_mrf = df8.loc[955:1623,'final'].sum()
rbd_q9_mrf = df9.loc[955:1623,'final'].sum()

# %%
b1_avg = [b1_q1_avg,b1_q2_avg,b1_q3_avg,b1_q4_avg]
delta_avg = [delta_q6_avg,delta_q7_avg,delta_q8_avg,delta_q9_avg]

ntd_b1_avg = [ntd_q1_avg,ntd_q2_avg,ntd_q3_avg,ntd_q4_avg]
ntd_delta_avg = [ntd_q6_avg,ntd_q7_avg,ntd_q8_avg,ntd_q9_avg]

rbd_b1_avg = [rbd_q1_avg,rbd_q2_avg,rbd_q3_avg,rbd_q4_avg]
rbd_delta_avg = [rbd_q6_avg,rbd_q7_avg,rbd_q8_avg,rbd_q9_avg]

b1_mrf = [b1_q1_mrf,b1_q2_mrf,b1_q3_mrf,b1_q4_mrf]
delta_mrf = [delta_q6_mrf,delta_q7_mrf,delta_q8_mrf,delta_q9_mrf]

ntd_b1_mrf = [ntd_q1_mrf,ntd_q2_mrf,ntd_q3_mrf,ntd_q4_mrf]
ntd_delta_mrf = [ntd_q6_mrf,ntd_q7_mrf,ntd_q8_mrf,ntd_q9_mrf]

rbd_b1_mrf = [rbd_q1_mrf,rbd_q2_mrf,rbd_q3_mrf,rbd_q4_mrf]
rbd_delta_mrf = [rbd_q6_mrf,rbd_q7_mrf,rbd_q8_mrf,rbd_q9_mrf]

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

label_mrf = ["Apr-Jun20","Jul-Sep20","Oct-Dec20","Jan-Mar21","April-Jun21","Jul-Sep21","Oct-Dec21"]
ticks_mrf = [0,1,2,3,4,5,6]

x1_mrf = np.arange(0,4)
x2_mrf = np.arange(3,7)

fig, axs = plt.subplots(2, 2, figsize=(24,12))
axs[0, 0].plot(x1_mrf, b1_avg, '-ro', label="B1 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].plot(x2_mrf, delta_avg, '-bo', label="Delta Surface Glycoprotein", linewidth=4.0)
axs[0, 0].legend(frameon=False, fontsize=20)
#axs[0, 0].set_ylabel("Cumulative Entropy", fontsize=15)
axs[0, 0].set_xticks(ticks_mrf,label_mrf)
axs[0, 0].tick_params(labelsize=18)
axs[0, 1].plot(x1_mrf,ntd_b1_avg, '-ro', label="B1 NTD", linewidth=4.0)
axs[0, 1].plot(x2_mrf,ntd_delta_avg, '-bo', label="Delta NTD", linewidth=4.0)
axs[0, 1].legend(frameon=False, fontsize=20)
#axs[0, 1].set_ylabel("Cumulative Entropy", fontsize=15)
axs[0, 1].set_xticks(ticks_mrf,label_mrf)
axs[0, 1].tick_params(labelsize=18)
axs[1, 0].plot(x1_mrf,b1_mrf, '-ro', label="B1 Surface Glycoprotein", linewidth=4.0)
axs[1, 0].plot(x2_mrf,delta_mrf, '-bo', label="Delta Surface Glycoprotein", linewidth=4.0)
axs[1, 0].legend(frameon=False, fontsize=20)
# axs[1, 0].set_ylabel("MRF", fontsize=15)
# axs[1, 0].set_xlabel("Timeline", fontsize=15)
axs[1, 0].tick_params(labelsize=18)
axs[1, 0].set_xticks(ticks_mrf,label_mrf)
axs[1, 1].plot(x1_mrf,ntd_b1_mrf, '-ro', label="B1 NTD", linewidth=4.0)
axs[1, 1].plot(x2_mrf,ntd_delta_mrf, '-bo', label="Delta NTD", linewidth=4.0)
axs[1, 1].legend(frameon=False, fontsize=20)
#axs[1, 1].tick_params(labelsize=12)
# axs[1, 1].set_xlabel("Timeline", fontsize=15)
# axs[1, 1].set_ylabel("MRF", fontsize=15)
axs[1, 1].set_xticks(ticks_mrf,label_mrf)
axs[1, 1].tick_params(labelsize=18)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_mrf_b1_delta_combine_2sep_sg_ntd_genomic.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
label_mrf = ["Apr-Jun20","Jul-Sep20","Oct-Dec20","Jan-Mar21","April-Jun21","Jul-Sep21","Oct-Dec21"]
ticks_mrf = [0,1,2,3,4,5,6]

x1_mrf = np.arange(0,4)
x2_mrf = np.arange(3,7)

plt.figure(figsize=(16,5))
plt.plot(x1_mrf,rbd_b1_avg, '-ro', linewidth=3.0, label="B1 RBD")
plt.plot(x2_mrf,rbd_delta_avg, '-bo', linewidth=3.0, label="Delta RBD")
plt.xticks(ticks_mrf,label_mrf, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
#plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/avg_b1_delta_combine_2sep_rbd_genomic.png", dpi=600)
plt.show()

plt.figure(figsize=(16,5))
plt.plot(x1_mrf,rbd_b1_mrf, '-ro', linewidth=3.0, label="B1 RBD")
plt.plot(x2_mrf,rbd_delta_mrf, '-bo', linewidth=3.0, label="Delta RBD")
plt.xticks(ticks_mrf,label_mrf, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=15)
#plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/mrf_b1_delta_combine_2sep_rbd_genomic.png", dpi=600)
plt.show()

# %%
b1_cumulative_mrf = [12.1053918573304,8.04863198867721,11.599318360104,15.5894834970138]
delta_cumulative_mrf = [29.6575495117875,25.589920276906,25.7996175996167,25.2957147554163]

ntd_q1 = df1.loc[33:910,'final'].sum()
ntd_q2 = df2.loc[33:910,'final'].sum()
ntd_q3 = df3.loc[33:910,'final'].sum()
ntd_q4 = df4.loc[33:910,'final'].sum()
ntd_q5 = df5.loc[33:910,'final'].sum()
ntd_q6 = df6.loc[33:910,'final'].sum()
ntd_q7 = df7.loc[33:910,'final'].sum()
ntd_q8 = df8.loc[33:910,'final'].sum()
ntd_q9 = df9.loc[33:910,'final'].sum()

rbd_q1 = df1.loc[955:1623,'final'].sum()
rbd_q2 = df2.loc[955:1623,'final'].sum()
rbd_q3 = df3.loc[955:1623,'final'].sum()
rbd_q4 = df4.loc[955:1623,'final'].sum()
rbd_q5 = df5.loc[955:1623,'final'].sum()
rbd_q6 = df6.loc[955:1623,'final'].sum()
rbd_q7 = df7.loc[955:1623,'final'].sum()
rbd_q8 = df8.loc[955:1623,'final'].sum()
rbd_q9 = df9.loc[955:1623,'final'].sum()

ntd_b1_mrf = [ntd_q1,ntd_q2,ntd_q3,ntd_q4]
ntd_delta_mrf = [ntd_q6,ntd_q7,ntd_q8,ntd_q9]

rbd_b1_mrf = [rbd_q1,rbd_q2,rbd_q3,rbd_q4]
rbd_delta_mrf = [rbd_q6,rbd_q7,rbd_q8,rbd_q9]

length1 = 3823
length2 = 877
length3 = 668

newList1 = [x / length1 for x in b1_cumulative_mrf]
newList2 = [x / length1 for x in delta_cumulative_mrf]
newList3 = [x / length2 for x in ntd_b1_mrf]
newList4 = [x / length2 for x in ntd_delta_mrf]
newList5 = [x / length3 for x in rbd_b1_mrf]
newList6 = [x / length3 for x in rbd_delta_mrf]

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False


label_mrf = ["Apr-Jun20","Jul-Sep20","Oct-Dec20","Jan-Mar21","April-Jun21","Jul-Sep21","Oct-Dec21"]
ticks_mrf = [0,1,2,3,4,5,6]

x1_ce = np.arange(0,10)
x2_ce = np.arange(9,19)
x1_mrf = np.arange(0,4)
x2_mrf = np.arange(3,7)

fig, axs = plt.subplots(2, 2, figsize=(18,10))
axs[0, 0].plot(x1_mrf,b1_mrf, '-ro', label="B1 Surface Glycoprotein", linewidth=4.0)
axs[0, 0].plot(x2_mrf, delta_mrf, '-bo', label="Delta Surface Glycoprotein", linewidth=4.0)
axs[0, 0].legend(frameon=False)
#axs[0, 0].set_ylabel("Cumulative Entropy", fontsize=15)
axs[0, 0].set_xticks(ticks_mrf,label_mrf)
axs[0, 0].tick_params(labelsize=12)
axs[0, 1].plot(x1_mrf,ntd_b1_mrf, '-ro', label="B1 NTD", linewidth=4.0)
axs[0, 1].plot(x2_mrf,ntd_delta_mrf, '-bo', label="Delta NTD", linewidth=4.0)
axs[0, 1].legend(frameon=False)
#axs[0, 1].set_ylabel("Cumulative Entropy", fontsize=15)
axs[0, 1].set_xticks(ticks_mrf,label_mrf)
axs[0, 1].tick_params(labelsize=12)
axs[1, 0].plot(x1_mrf,newList1, '-ro', label="B1 Surface GLycoprotein", linewidth=4.0)
axs[1, 0].plot(x2_mrf,newList2, '-bo', label="Delta Surface GLycoprotein", linewidth=4.0)
axs[1, 0].legend(frameon=False)
# axs[1, 0].set_ylabel("MRF", fontsize=15)
# axs[1, 0].set_xlabel("Timeline", fontsize=15)
axs[1, 0].tick_params(labelsize=12)
axs[1, 0].set_xticks(ticks_mrf,label_mrf)
axs[1, 1].plot(x1_mrf,newList3, '-ro', label="B1 NTD", linewidth=4.0)
axs[1, 1].plot(x2_mrf,newList4, '-bo', label="Delta NTD", linewidth=4.0)
axs[1, 1].legend(frameon=False)
#axs[1, 1].tick_params(labelsize=12)
# axs[1, 1].set_xlabel("Timeline", fontsize=15)
# axs[1, 1].set_ylabel("MRF", fontsize=15)
axs[1, 1].set_xticks(ticks_mrf,label_mrf)
axs[1, 1].tick_params(labelsize=12)
#plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/30August_final_revised_graphs/ce_mrf_b1_delta_combine_30aug_sg_ntd_genomic_new.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
b1_mrf_sup = [b1_q2_mrf,b1_q3_mrf,b1_q4_mrf]
delta_mrf_sup = [delta_q6_mrf,delta_q7_mrf,delta_q8_mrf]

x1_mrf_sup = np.arange(0,3)
x2_mrf_sup = np.arange(2,5)

plt.figure(figsize=(12,6))
plt.plot(x1_mrf_sup,b1_mrf_sup, '-ro', label="B1 Surface Glycoprotein", linewidth=5.0)
plt.plot(x2_mrf_sup, delta_mrf_sup, '-bo', label="Delta Surface Glycoprotein", linewidth=5.0)
plt.xticks([])
plt.yticks([])
#plt.legend(frameon=False, fontsize=20)
plt.savefig("/home/satyam/Documents/Projects/Entropy_Comparison/Revision/mrf_sup.png",dpi=600, bbox_inches='tight')
plt.show()
