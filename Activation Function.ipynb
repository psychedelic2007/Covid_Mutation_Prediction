# %%
import matplotlib.pyplot as plt
import numpy as np

def sigmoid(x):
    s=1/(1+np.exp(-x))
    ds=s*(1-s)  
    return s,ds
xs=np.arange(-6,6,0.01)
sigmoid(xs)
# Setup centered axes
fig, ax = plt.subplots(figsize=(18, 10))
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
# Create and show plot
ax.plot(x,sigmoid(x)[0], color="#307EC7", linewidth=3, label="sigmoid")
#ax.plot(x,sigmoid(x)[1], color="#9621E2", linewidth=3, label="derivative")
ax.legend(frameon=False, fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.savefig("sigmoid_act_func.png", dpi=600)
fig.show()
# Out:
# /home/satyam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

def tanh(x):
    t=(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))
    dt=1-t**2
    return t,dt
z=np.arange(-3,3,0.01)
tanh(z)[0].size,tanh(z)[1].size
# Setup centered axes
fig, ax = plt.subplots(figsize=(18, 10))
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
# Create and show plot
ax.plot(z,tanh(z)[0], color="#307EC7", linewidth=3, label="tanh")
#ax.plot(z,tanh(z)[1], color="#9621E2", linewidth=3, label="derivative")
ax.legend(frameon=False, fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.savefig("tanh_act_func.png", dpi=600)
fig.show()
# Out:
# /home/satyam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
def RELU(x):
    ''' It returns zero if the input is less than zero otherwise it returns the given input. '''
    x1=[]
    for i in x:
        if i<0:
            x1.append(0)
        else:
            x1.append(i)
    return x1

xr = np.linspace(-4, 4)
fig, ax = plt.subplots(figsize=(18, 10))
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
# Create and show plot
ax.plot(xr,RELU(xr), color="#307EC7", linewidth=3, label="ReLU")
ax.legend(frameon=False, fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.savefig("relu_act_func.png", dpi=600)
fig.show()
# Out:
# /home/satyam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.plot(x,sigmoid(x)[0], color="red", linewidth=3, label="sigmoid")
ax.plot(z,tanh(z)[0], color="black", linewidth=3, label="tanh")
ax.plot(xr,RELU(xr), color="green", linewidth=3, label="ReLU")
ax.legend(frameon=False, fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.savefig("act_func.png", dpi=600)
fig.show()
# Out:
# /home/satyam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

def RELU(x):
    ''' It returns zero if the input is less than zero otherwise it returns the given input. '''
    x1=[]
    for i in x:
        if i<0:
            x1.append(0)
        else:
            x1.append(i)
    return x1

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(-1,1,100)
    y = RELU(x)
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()

# %%
# import required modules
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
 
def updateline(num, data, line1, data2, line2, data3, line3):
    line1.set_data(data[..., :num])
    line2.set_data(data2[..., :num])
    line3.set_data(data3[..., :num])
    time_text.set_text("Points: %.0f" % int(num))
    return line1, line2, line3
 
# generating data of 100 elements
# each for line 1
x = np.linspace(-3, 3, 100)
y = RELU(x)
data = np.array([x, y])
 
# generating data of 100 elements
# each for line 2
x2 = np.linspace(-3, -3, 100)
y2 = tanh(x2)[0]
data2 = np.array([x2, y2])

x3 = np.linspace(-6,6, 100)
y3 = sigmoid(x3)[0]
data3 = np.array([x3,y3])

# setup the formating for moving files
Writer = animation.writers['ffmpeg']
Writer = Writer(fps=10, metadata=dict(artist="Me"), bitrate=-1)
 
fig = plt.figure()
ax = fig.add_subplot(111)
l, = ax.plot([], [], 'r-', label="ReLU")
ax2 = ax.twinx()
k = ax2.plot([], [], 'b-', label="TanH")[0]
ax3 = ax.twinx()
m = ax3.plot([], [], 'g', label="Sigmoid")[0]
 
ax.legend([l, k, m], [l.get_label(), k.get_label(), m.get_label()], loc=0)
 
ax.set_xlabel("X")
 
# axis 1
ax.set_ylim(-1.5, 1.5)
ax.set_xlim(-1, 7)
 
# axis 2
ax2.set_ylim(-1.5, 1.5)
ax2.set_xlim(-1, 7)

ax3.set_ylim(0,1)
ax3.set_xlim(-6,6)
 
plt.title('Activation')
time_text = ax.text(0.1, 0.95, "", transform=ax.transAxes,fontsize=15, color='red')
 
# set line_animation variable to call
# the function recursively
line_animation = animation.FuncAnimation(
    fig, updateline, frames=100, fargs=(data, l, data2, k, data3, m))
line_animation.save("lines.mp4", writer=Writer)

# %%
# import required modules
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
 
def updateline(num, data, line1):
    line1.set_data(data[..., :num])
    time_text.set_text("Points: %.0f" % int(num))
    time_text2.set_text("")
    return line1
 
# generating data of 100 elements
# each for line 1
x = np.linspace(-3, 3, 100)
y = RELU(x)
data = np.array([x, y])

# setup the formating for moving files
Writer = animation.writers['ffmpeg']
Writer = Writer(fps=10, metadata=dict(artist="Me"), bitrate=500)
 
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111)
l, = ax.plot([], [], 'r-', label="ReLU", linewidth=3.0)
ax.legend([l], [l.get_label()], prop={'size': 20})
ax.set_xlabel("X")
ax.set_ylabel("Y")
 
# axis 1
ax.set_ylim(-1,5)
ax.set_xlim(-3,3)
ax.tick_params(axis="x", labelsize=24)
ax.tick_params(axis="y", labelsize=24)
plt.title('Activation', fontsize=28)
plt.xlabel("X", fontsize=20)
plt.ylabel("Y", fontsize=20)
time_text = ax.text(0.1, 0.95, "", transform=ax.transAxes,fontsize=28, color='black')
 
# set line_animation variable to call
# the function recursively
line_animation = animation.FuncAnimation(fig, updateline, frames=100, fargs=(data,l))
line_animation.save("relu_act_animation.mp4", writer=Writer)

# %%
# import required modules
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
 
def updateline(num, data, line1):
    line1.set_data(data[..., :num])
    time_text.set_text("Points: %.0f" % int(num))
    return line1
 
# generating data of 100 elements
# each for line 1
x = np.linspace(-6, 6, 100)
y = sigmoid(x)[0]
data = np.array([x, y])

# setup the formating for moving files
Writer = animation.writers['ffmpeg']
Writer = Writer(fps=10, metadata=dict(artist="Me"), bitrate=500)
 
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111)
l, = ax.plot([], [], 'g-', label="Sigmoid", linewidth=3.0)
ax.legend([l], [l.get_label()], prop={'size': 20})
ax.set_xlabel("X")
ax.set_ylabel("Y")
 
# axis 1
ax.set_ylim(0,1)
ax.set_xlim(-6,6)
ax.tick_params(axis="x", labelsize=24)
ax.tick_params(axis="y", labelsize=24)
plt.title('Activation', fontsize=28)
plt.xlabel("X", fontsize=20)
plt.ylabel("Y", fontsize=20)
time_text = ax.text(0.1, 0.95, "", transform=ax.transAxes,fontsize=28, color='black')
 
# set line_animation variable to call
# the function recursively
line_animation = animation.FuncAnimation(
    fig, updateline, frames=100, fargs=(data, l))
line_animation.save("sigmoid_act_animation.mp4", writer=Writer)

# %%
# import required modules
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
 
def updateline(num, data, line1, data2, line2):
    line1.set_data(data[..., :num])
    line2.set_data(data2[..., :num])
    time_text.set_text("Points: %.0f" % int(num))
    return line1, line2
 
# generating data of 100 elements
# each for line 1
x = np.linspace(-6, 6, 100)
y = tanh(x)[0]
data = np.array([x, y])

x2 = np.linspace(-6,6,100)
y2 = sigmoid(x2)[0]
data2 = np.array([x2,y2])

# setup the formating for moving files
Writer = animation.writers['ffmpeg']
Writer = Writer(fps=10, metadata=dict(artist="Me"), bitrate=1000)
 
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111)
l, = ax.plot([], [], 'b-', label="TanH", linewidth=3.0)
ax2 = ax.twinx()
k, = ax2.plot([],[], 'g-', label="Sigmoid", linewidth=3.0)
ax.legend([l, k], [l.get_label(), k.get_label()], prop={'size': 20})
ax.set_xlabel("X")
ax.set_ylabel("Y")
 
# axis 1
ax.set_ylim(-1,1)
ax.set_xlim(-6,6)
ax2.set_ylim(-1,1)
ax2.set_xlim(-6,6)
ax.tick_params(axis="x", labelsize=24)
ax.tick_params(axis="y", labelsize=24)
ax2.tick_params(axis="x", labelsize=24)
ax2.tick_params(axis="y", labelsize=24)
plt.title('Activation', fontsize=28)
plt.xlabel("X", fontsize=30)
plt.ylabel("Y", fontsize=30)
time_text = ax.text(0.1, 0.95, "", transform=ax.transAxes,fontsize=28, color='black')
 
# set line_animation variable to call
# the function recursively
line_animation = animation.FuncAnimation(
    fig, updateline, frames=100, fargs=(data, l, data2, k))
line_animation.save("tanh_sig__act_animation.mp4", writer=Writer)
